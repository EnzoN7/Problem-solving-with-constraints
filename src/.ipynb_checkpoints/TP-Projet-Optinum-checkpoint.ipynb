# %% [markdown]
# <center>
# <h1> TP-Projet d'optimisation numérique </h1>
# <h1> Année 2020-2021 - 2e année département Sciences du Numérique </h1>
# <h1> Nom: DI MARIA </h1>
# <h1> Prénom: Enzo </h1>
# </center>

# %% [markdown]
# # Algorithme de Newton
# ## Implémentation
#
# 1. Coder l’algorithme de Newton local tel que décrit dans la section *Algorithme de Newton* (fichier `Algorithme_De_Newton.jl`)
#
# 2. Tester l’algorithme sur les fonctions $f_{1}$ , $f_{2}$ avec les points initiaux $x_{011}$ , $x_{012}$ (pour $f_{1}$ ) et $x_{021}$ , $x_{022}$ , $x_{023}$ (pour $f_{2}$ ) donnés en Annexe A.

# %%
using Pkg
Pkg.status()
# Out:
# Status `~/2A/Optimisation/optinum/src/Project.toml`
#   (empty environment)

# %%
#using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
#using Documenter
using LinearAlgebra
using Markdown                             # Pour que les docstrings en début des fonctions ne posent
                                           # pas de soucis. Ces docstrings sont utiles pour générer 
                                           # la documentation sous GitHub

include("Algorithme_De_Newton.jl")

# Affichage les sorties de l'algorithme des Régions de confiance
function my_afficher_resultats(algo,nom_fct,point_init,xmin,fxmin,flag,sol_exacte,nbiters)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : ",algo, " appliqué à ",nom_fct, " au point initial ", point_init, ":\n",bold=true,color=:blue)
	println("  * xsol = ",xmin)
	println("  * f(xsol) = ",fxmin)
	println("  * nb_iters = ",nbiters)
	println("  * flag = ",flag)
	println("  * sol_exacte : ", sol_exacte)
end

# Fonction f0
# -----------
f0(x) =  sin(x)
# la gradient de la fonction f0
grad_f0(x) = cos(x)
# la hessienne de la fonction f0
hess_f0(x) = -sin(x)
sol_exacte = -pi/2
options = []

x0 = sol_exacte
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f0,grad_f0,hess_f0,x0,options)
my_afficher_resultats("Newton","f0",x0,xmin,f_min,flag,sol_exacte,nb_iters)
x0 = -pi/2+0.5
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f0,grad_f0,hess_f0,x0,options)
my_afficher_resultats("Newton","f0",x0,xmin,f_min,flag,sol_exacte,nb_iters)
x0 = pi/2
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f0,grad_f0,hess_f0,x0,options)
my_afficher_resultats("Newton","f0",x0,xmin,f_min,flag,sol_exacte,nb_iters)
println("-------------------------------------------------------------------------")

# Exemples de l'annexe A
# -----------
f1(x) = 2 * (x[1] + x[2] + x[3] - 3)^2 + (x[1] - x[2])^2 + (x[2] - x[3])^2
grad_f1(x) = [6*x[1] + 2*x[2] + 4*x[3] - 12 ; 2*x[1] + 8*x[2] + 2*x[3] - 12 ; 4*x[1] + 2*x[2] + 6*x[3] - 12]
hess_f1(x) = [[6 2 4] ; [2 8 2] ; [4 2 6]]

sol_exacte = [1 ; 1 ; 1]
x011 = [1 ; 0 ; 0]
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f1,grad_f1,hess_f1,x011,options)
my_afficher_resultats("Newton","f1",x011,xmin,f_min,flag,sol_exacte,nb_iters)
x012 = [10 ; 3 ; -2.2]
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f1,grad_f1,hess_f1,x012,options)
my_afficher_resultats("Newton","f1",x012,xmin,f_min,flag,sol_exacte,nb_iters)
println("-------------------------------------------------------------------------")

f2(x) = 100 * (x[2] - x[1]^2)^2 + (1 - x[1])^2
grad_f2(x) = [400*x[1]^3 - 400*x[1]*x[2] + 2*x[1] - 2 ; -200*x[1]^2 + 200*x[2]]
hess_f2(x) = [[1200*x[1]^2 - 400*x[2] + 2 -400*x[1]] ; [-400*x[1] 200]]

sol_exacte = [1 ; 1]
x021 = [-1.2 ; 1]
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f2,grad_f2,hess_f2,x021,options)
my_afficher_resultats("Newton","f2",x021,xmin,f_min,flag,sol_exacte,nb_iters)
x022 = [10 ; 0]
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f2,grad_f2,hess_f2,x022,options)
my_afficher_resultats("Newton","f2",x022,xmin,f_min,flag,sol_exacte,nb_iters)
x023 = [0 ; (1/200) + (1/10^12)]
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f2,grad_f2,hess_f2,x023,options)
my_afficher_resultats("Newton","f2",x023,xmin,f_min,flag,sol_exacte,nb_iters)
# Out:
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0 au point initial -1.5707963267948966:
#   * xsol = -1.5707963267948966
#   * f(xsol) = -1.0
#   * nb_iters = 0
#   * flag = -1
#   * sol_exacte : -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0 au point initial -1.0707963267948966:
#   * xsol = -1.5707963267949088
#   * f(xsol) = -1.0
#   * nb_iters = 3
#   * flag = 0
#   * sol_exacte : -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0 au point initial 1.5707963267948966:
#   * xsol = 1.5707963267948966
#   * f(xsol) = 1.0
#   * nb_iters = 0
#   * flag = -1
#   * sol_exacte : -1.5707963267948966
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f1 au point initial [1, 0, 0]:
#   * xsol = [1.0, 1.0, 0.9999999999999999]
#   * f(xsol) = 1.232595164407831e-32
#   * nb_iters = 1
#   * flag = 0
#   * sol_exacte : [1, 1, 1]
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f1 au point initial [10.0, 3.0, -2.2]:
#   * xsol = [0.9999999999999982, 0.9999999999999996, 1.0000000000000009]
#   * f(xsol) = 7.099748146989106e-30
#   * nb_iters = 1
#   * flag = 0
#   * sol_exacte : [1, 1, 1]
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f2 au point initial [-1.2, 1.0]:
#   * xsol = [0.9999999999999998, 0.999999999981472]
#   * f(xsol) = 3.432687326759487e-20
#   * nb_iters = 6
#   * flag = 0
#   * sol_exacte : [1, 1]
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f2 au point initial [10, 0]:
#   * xsol = [1.0, 1.0]
#   * f(xsol) = 0.0
#   * nb_iters = 5
#   * flag = 0
#   * sol_exacte : [1, 1]
# SingularException(2)
#
# Stacktrace:
#  [1] checknonsingular at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.4/LinearAlgebra/src/factorization.jl:19 [inlined]
#  [2] checknonsingular at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.4/LinearAlgebra/src/factorization.jl:21 [inlined]
#  [3] lu!(::Array{Float64,2}, ::Val{true}; check::Bool) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.4/LinearAlgebra/src/lu.jl:85
#  [4] #lu#142 at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.4/LinearAlgebra/src/lu.jl:273 [inlined]
#  [5] lu at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.4/LinearAlgebra/src/lu.jl:272 [inlined] (repeats 2 times)
#  [6] \(::Array{Float64,2}, ::Array{Float64,1}) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.4/LinearAlgebra/src/generic.jl:1116
#  [7] Algorithme_De_Newton(::typeof(f2), ::typeof(grad_f2), ::typeof(hess_f2), ::Array{Float64,1}, ::Array{Any,1}) at /home/edimaria/2A/Optimisation/optinum/src/Algorithme_De_Newton.jl:64
#  [8] top-level scope at In[25]:69

# %% [markdown]
# ## Interprétation
#
# Justifier
#
# 1. les résultats obtenus pour l'exemple $f_0$ ci-dessus;
#
# 2. que l’algorithme implémenté converge en une itération pour $f_{1}$;
#
# 3. que l’algorithme puisse ne pas converger pour $f_{2}$ avec certains points initiaux.

# %% [markdown]
# ## Vos réponses?
#
# 1. L'algorithme converge en une itération vers $-1$ pour le premier exemple, car le point initial est justement la solution recherchée $-\frac{\pi}{2}$. De la même façon, le troisième exemple converge immédiatement car le point initial $\frac{\pi}{2}$ correspond à un point critique. Enfin, le deuxième converge en trois itérations vers $-\frac{\pi}{2}$ car le point initial en est le voisin.
#
# 2. L'algorithme converge si vite pour $f_1$ car elle est quadratique.
#
# 3. L'algorithme ne converge pas dans le test de $f_2$ dont le point de départ est $x_{023}$ car la matrice hessienne associée est singulière.

# %% [markdown]
# # Régions de confiance avec pas de cauchy
#
# ## Implémentation
#
# 1. Coder l'algorithme du pas de Cauchy d’un sous-problème de
# régions de confiance (fichier `Pas_De_Cauchy.jl`). Tester sur les quadratiques proposées en Annexe B.
#
# 2. Coder l'algorithme de régions de confiance (fichier `Regions_De_Confiance.jl`). Tester sur les problèmes de l’Annexe A.

# %%
# Vos tests
using LinearAlgebra
using Markdown
using Test

include("../test/fonctions_de_tests.jl")
include("../test/tester_algo_newton.jl")
include("../test/tester_pas_de_cauchy.jl")
include("../test/tester_gct.jl")
include("../test/tester_regions_de_confiance.jl")
include("../test/tester_lagrangien_augmente.jl")

include("Regions_De_Confiance.jl")
include("Gradient_Conjugue_Tronque.jl")
include("Pas_De_Cauchy.jl")

tester_regions_de_confiance(true, Regions_De_Confiance)
tester_pas_de_cauchy(true, Pas_De_Cauchy)
# Out:
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec cauchy appliqué à fonction 1 au point initial x011 :
#   * xsol = [1.0000000310867154, 0.9999999957837182, 0.999999960480721]
#   * f(xsol) = 2.812589785349316e-15
#   * nb_iters = 48
#   * flag = 0
#   * sol_exacte : [1, 1, 1]
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec cauchy appliqué à fonction 1 au point initial x012 :
#   * xsol = [1.0000001114825787, 0.9999999912691591, 0.9999998710557396]
#   * f(xsol) = 3.027462898391515e-14
#   * nb_iters = 42
#   * flag = 0
#   * sol_exacte : [1, 1, 1]
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec cauchy appliqué à fonction 2 au point initial x021 :
#   * xsol = [0.9993529197811677, 0.9987042941131304]
#   * f(xsol) = 4.190986028460228e-7
#   * nb_iters = 5000
#   * flag = 3
#   * sol_exacte : [1, 1]
# iters = 864
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec cauchy appliqué à fonction 2 au point initial x022 :
#   * xsol = [0.9961677295959247, 0.9923393628794702]
#   * f(xsol) = 1.4697922915267688e-5
#   * nb_iters = 864
#   * flag = 0
#   * sol_exacte : [1, 1]
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec cauchy appliqué à fonction 2 au point initial x023 :
#   * xsol = [0.9999372227347163, 0.999873853121763]
#   * f(xsol) = 3.976541052455946e-9
#   * nb_iters = 5000
#   * flag = 3
#   * sol_exacte : [1, 1]
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec gct appliqué à fonction 1 au point initial x011 :
#   * xsol = [1.0000000000000002, 1.0000000000000002, 1.0000000000000004]
#   * f(xsol) = 1.627025617018337e-30
#   * nb_iters = 1
#   * flag = 0
#   * sol_exacte : [1, 1, 1]
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec gct appliqué à fonction 1 au point initial x012 :
#   * xsol = [0.9999999999999991, 1.0, 1.0000000000000018]
#   * f(xsol) = 5.5220263365470826e-30
#   * nb_iters = 3
#   * flag = 0
#   * sol_exacte : [1, 1, 1]
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec gct appliqué à fonction 2 au point initial x021 :
#   * xsol = [0.999999674378009, 0.9999993478371609]
#   * f(xsol) = 1.0611413034983129e-13
#   * nb_iters = 31
#   * flag = 0
#   * sol_exacte : [1, 1]
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec gct appliqué à fonction 2 au point initial x022 :
#   * xsol = [1.000003518300986, 1.0000066949336197]
#   * f(xsol) = 2.4053014025360875e-11
#   * nb_iters = 44
#   * flag = 0
#   * sol_exacte : [1, 1]
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec gct appliqué à fonction 2 au point initial x023 :
#   * xsol = [1.0000000000000002, 1.0000000000000002, 1.0000000000000004]
#   * f(xsol) = 3.1813581453548166e-24
#   * nb_iters = 19
#   * flag = 0
#   * sol_exacte : [1, 1]
# Test Summary:      | Pass  Total
# La méthode des RC  |   10     10
# Test Summary: | Pass  Total
# Pas de Cauchy |    7      7
# Test.DefaultTestSet("Pas de Cauchy", Any[Test.DefaultTestSet("g = 0", Any[], 1, false), Test.DefaultTestSet("quad 2, non saturé", Any[], 1, false), Test.DefaultTestSet("quad 2, saturé", Any[], 1, false), Test.DefaultTestSet("quad 3, non saturé", Any[], 1, false), Test.DefaultTestSet("quad 3, saturé", Any[], 1, false), Test.DefaultTestSet("quad 3, g'*H*g <0 saturé", Any[], 1, false), Test.DefaultTestSet("quad 3, g'*H*g = 0 saturé", Any[], 1, false)], 0, false)

# %% [markdown]
# ## Interprétation
#
# 1. Quelle relation lie la fonction test $f_1$ et son modèle de Taylor à l’ordre 2 ? Comparer alors les performances de Newton et RC-Pas de Cauchy sur cette fonction.
#
# 2. Le rayon initial de la région de confiance est un paramètre important dans l’analyse
# de la performance de l’algorithme. Sur quel(s) autre(s) paramètre(s) peut-on jouer
# pour essayer d’améliorer cette performance ? Étudier l’influence d’au moins deux de
# ces paramètres.

# %% [markdown]
# ## Vos réponses?
#
# 1. La relation liant $f_1$ et son modèle de Taylor à l'ordre 2 $m_k$ est
# $$m_k(x_k + s) = f_1(x_k) + g_k^Ts + \frac{1}{2}s^TH_ks$$
# On remarque en premier lieu que l'algorithme des régions de confiance utilisant le pas de Cauchy est plus robuste que l'algorithme de Newton. En effet le test de $f_2$ dont le point de départ est $x_{023}$ ne renvoie pas d'exception. En revanche, les performances sont moindres car la convergence est moins rapide.
#
# 2. D'autres paramètres sur lesquels on peut jouer sont $\Delta_0$, $\eta_1$, $\eta_2$. Le premier, car il influe sur le déroulement du pas de Cauchy et les deux suivants, car ils ont un rôle dans la mise à jour de la région de confiance.

# %% [markdown]
# # Régions de confiance avec gradient conjugué tronqué
#
# ## Implémentation
#
# 1. Implémenter l’algorithme du Gradient Conjugué Tronqué, en se basant sur le cours (fichier `Gradient_Conjugue_Tronque.jl`).
# On validera les résultats sur les fonctions de l’Annexe C.
#
# 2. Intégrer finalement l’algorithme du Gradient Conjugué Tronqué dans le code de
# régions de confiance, et appliquer ce code pour résoudre les exemples proposés en
# Annexe A.

# %%
# Vos tests
using LinearAlgebra
using Markdown
using Test

include("../test/fonctions_de_tests.jl")
include("../test/tester_algo_newton.jl")
include("../test/tester_pas_de_cauchy.jl")
include("../test/tester_gct.jl")
include("../test/tester_regions_de_confiance.jl")
include("../test/tester_lagrangien_augmente.jl")

include("Regions_De_Confiance.jl")
include("Gradient_Conjugue_Tronque.jl")
include("Pas_De_Cauchy.jl")

tester_regions_de_confiance(true, Regions_De_Confiance)
tester_gct(true, Gradient_Conjugue_Tronque)
# Out:
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec cauchy appliqué à fonction 1 au point initial x011 :
#   * xsol = [1.0000000310867154, 0.9999999957837182, 0.999999960480721]
#   * f(xsol) = 2.812589785349316e-15
#   * nb_iters = 48
#   * flag = 0
#   * sol_exacte : [1, 1, 1]
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec cauchy appliqué à fonction 1 au point initial x012 :
#   * xsol = [1.0000001114825787, 0.9999999912691591, 0.9999998710557396]
#   * f(xsol) = 3.027462898391515e-14
#   * nb_iters = 42
#   * flag = 0
#   * sol_exacte : [1, 1, 1]
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec cauchy appliqué à fonction 2 au point initial x021 :
#   * xsol = [0.9993529197811677, 0.9987042941131304]
#   * f(xsol) = 4.190986028460228e-7
#   * nb_iters = 5000
#   * flag = 3
#   * sol_exacte : [1, 1]
# iters = 864
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec cauchy appliqué à fonction 2 au point initial x022 :
#   * xsol = [0.9961677295959247, 0.9923393628794702]
#   * f(xsol) = 1.4697922915267688e-5
#   * nb_iters = 864
#   * flag = 0
#   * sol_exacte : [1, 1]
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec cauchy appliqué à fonction 2 au point initial x023 :
#   * xsol = [0.9999372227347163, 0.999873853121763]
#   * f(xsol) = 3.976541052455946e-9
#   * nb_iters = 5000
#   * flag = 3
#   * sol_exacte : [1, 1]
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec gct appliqué à fonction 1 au point initial x011 :
#   * xsol = [1.0000000000000002, 1.0000000000000002, 1.0000000000000004]
#   * f(xsol) = 1.627025617018337e-30
#   * nb_iters = 1
#   * flag = 0
#   * sol_exacte : [1, 1, 1]
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec gct appliqué à fonction 1 au point initial x012 :
#   * xsol = [0.9999999999999991, 1.0, 1.0000000000000018]
#   * f(xsol) = 5.5220263365470826e-30
#   * nb_iters = 3
#   * flag = 0
#   * sol_exacte : [1, 1, 1]
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec gct appliqué à fonction 2 au point initial x021 :
#   * xsol = [0.999999674378009, 0.9999993478371609]
#   * f(xsol) = 1.0611413034983129e-13
#   * nb_iters = 31
#   * flag = 0
#   * sol_exacte : [1, 1]
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec gct appliqué à fonction 2 au point initial x022 :
#   * xsol = [1.000003518300986, 1.0000066949336197]
#   * f(xsol) = 2.4053014025360875e-11
#   * nb_iters = 44
#   * flag = 0
#   * sol_exacte : [1, 1]
# -------------------------------------------------------------------------
# Résultats de : régions de confiance avec gct appliqué à fonction 2 au point initial x023 :
#   * xsol = [1.0000000000000002, 1.0000000000000002, 1.0000000000000004]
#   * f(xsol) = 3.1813581453548166e-24
#   * nb_iters = 19
#   * flag = 0
#   * sol_exacte : [1, 1]
# Test Summary:      | Pass  Total
# La méthode des RC  |   10     10
# Test Summary: | Pass  Total
# Gradient-CT   |    9      9
# Test.DefaultTestSet("Gradient-CT", Any[], 9, false)

# %% [markdown]
# ## Interprétation
#
# 1. Comparer la décroissance obtenue avec celle du pas de Cauchy, en retournant, dans
# un premier temps le dernier itéré admissible à courbure positive (c’est à dire, que si
# l’une ou l’autre des deux conditions (b) ou (d) sont rencontrées dans l’algorithme 3,
# alors on ne calcule pas ``σ_{j}`` et on retourne le dernier itéré ``s_{j}`` directement).
#
# 2. Comparer la décroissance obtenue avec celle du pas de Cauchy, en imposant la sortie
# dans l’algorithme 3 au bout d’une itération seulement. Que remarquez vous ?
#
# 3. Comparer la décroissance obtenue avec celle du pas de Cauchy dans le cas général.
#
# 4. Quels sont les avantages et inconvénients des deux approches ?

# %% [markdown]
# ## Vos réponses?
#
# 1. On remarque que, selon les cas, le fait de ne pas calculer $\sigma_j$ renvoie un $f(s_j)$ parfois très haut. Par exemple, le test de $f_2$ dont le point de départ est $x_{022}$ renvoie $1000081$. Pourtant il suffit de laisser le calcul de $\sigma_j$ se faire pour qu'il renvoie une valeur proche de $0$. On en déduit que la décroissance de GCT est très forte par rapport au pas de Cauchy.
#
# 2. Cela renvoie une erreur : s = nothing.
#
# 3. De façon générale, on constate que GCT fait converger l'algorithme bien plus rapidemment que le pas de Cauchy, tout en étant lui aussi robuste.
#
# 4. L'approche GCT fait converger le tout plus vite, mais est aussi plus délicat à implémenter et est plus gourmand en ressources, car c'est une boucle, là où l'autre se fait en une unique itération.

# %% [markdown]
# # Lagrangien augmenté
#
# ## Implémentation
# 1.Choisir des critères d’arrêt pour la convergence de l'algorithme.
#
# 2.Implémenter l'algorithme du lagrangien augmenté, en utilisant les différentes méthodes
# qui ont été vues en première partie pour la résolution de la suite de problémes sans
# contraintes (fichier `Lagrangien_Augmente.jl`)
#
# 3.Tester les différentes variantes sur les problèmes en Annexe D.

# %%
# Vos tests

using Markdown
using Test
using LinearAlgebra
include("../test/fonctions_de_tests.jl")
include("../test/tester_algo_newton.jl")
include("../test/tester_pas_de_cauchy.jl")
include("../test/tester_gct.jl")
include("../test/tester_regions_de_confiance.jl")
include("../test/tester_lagrangien_augmente.jl")

include("Lagrangien_Augmente.jl")
include("Algorithme_De_Newton.jl")

tester_lagrangien_augmente(true, Lagrangien_Augmente)
# Out:
# -------------------------------------------------------------------------
# Résultats de : Lagrangien augmenté avec newton appliqué à fonction 1 au point initial x01 :
#   * xsol = [0.50000000016907, 1.249999999915465, 0.5000000001690699]
#   * f(xsol) = 2.2499999984783696
#   * nb_iters = 11
#   * flag = 0
#   * sol_exacte : [0.5, 1.25, 0.5]
# -------------------------------------------------------------------------
# Résultats de : Lagrangien augmenté avec newton appliqué à fonction 1 au point initial x02 :
#   * xsol = [0.5000000120317551, 1.2499999939841218, 0.5000000120317575]
#   * f(xsol) = 2.249999891714194
#   * nb_iters = 9
#   * flag = 0
#   * sol_exacte : [0.5, 1.25, 0.5]
# -------------------------------------------------------------------------
# Résultats de : Lagrangien augmenté avec newton appliqué à fonction 2 au point initial x03 :
#   * xsol = [0.9072338859288398, 0.8227553207254552]
#   * f(xsol) = 0.008615664513977224
#   * nb_iters = 5
#   * flag = 0
#   * sol_exacte : [0.9072339605110892, 0.82275545631455]
# -------------------------------------------------------------------------
# Résultats de : Lagrangien augmenté avec newton appliqué à fonction 2 au point initial x04 :
#   * xsol = [0.9072339603128341, 0.8227554559541261]
#   * f(xsol) = 0.008615650696735408
#   * nb_iters = 6
#   * flag = 0
#   * sol_exacte : [0.9072339605110892, 0.82275545631455]
# -------------------------------------------------------------------------
# Résultats de : Lagrangien augmenté avec gct appliqué à fonction 1 au point initial x01 :
#   * xsol = [0.5000000001690731, 1.2499999999154643, 0.5000000001690705]
#   * f(xsol) = 2.249999998478354
#   * nb_iters = 11
#   * flag = 0
#   * sol_exacte : [0.5, 1.25, 0.5]
# -------------------------------------------------------------------------
# Résultats de : Lagrangien augmenté avec gct appliqué à fonction 1 au point initial x02 :
#   * xsol = [0.5000000120317012, 1.2499999939841338, 0.5000000120317041]
#   * f(xsol) = 2.249999891714678
#   * nb_iters = 9
#   * flag = 0
#   * sol_exacte : [0.5, 1.25, 0.5]
# -------------------------------------------------------------------------
# Résultats de : Lagrangien augmenté avec gct appliqué à fonction 2 au point initial x03 :
#   * xsol = [0.9072338859309047, 0.8227553207236404]
#   * f(xsol) = 0.008615664513947838
#   * nb_iters = 5
#   * flag = 0
#   * sol_exacte : [0.9072339605110892, 0.82275545631455]
# -------------------------------------------------------------------------
# Résultats de : Lagrangien augmenté avec gct appliqué à fonction 2 au point initial x04 :
#   * xsol = [0.9072339603128341, 0.8227554559541261]
#   * f(xsol) = 0.008615650696735408
#   * nb_iters = 6
#   * flag = 0
#   * sol_exacte : [0.9072339605110892, 0.82275545631455]
# -------------------------------------------------------------------------
# Résultats de : Lagrangien augmenté avec cauchy appliqué à fonction 1 au point initial x01 :
#   * xsol = [0.49999992784682384, 1.2500000007355867, 0.5000000699242212]
#   * f(xsol) = 2.2500000100303073
#   * nb_iters = 11
#   * flag = 0
#   * sol_exacte : [0.5, 1.25, 0.5]
# -------------------------------------------------------------------------
# Résultats de : Lagrangien augmenté avec cauchy appliqué à fonction 1 au point initial x02 :
#   * xsol = [0.49999995485094856, 1.2499999940035837, 0.5000000703952887]
#   * f(xsol) = 2.2499998863919397
#   * nb_iters = 9
#   * flag = 0
#   * sol_exacte : [0.5, 1.25, 0.5]
# -------------------------------------------------------------------------
# Résultats de : Lagrangien augmenté avec cauchy appliqué à fonction 2 au point initial x03 :
#   * xsol = [0.9072338858449457, 0.8227553206514825]
#   * f(xsol) = 0.008615664524565513
#   * nb_iters = 5
#   * flag = 0
#   * sol_exacte : [0.9072339605110892, 0.82275545631455]
# -------------------------------------------------------------------------
# Résultats de : Lagrangien augmenté avec cauchy appliqué à fonction 2 au point initial x04 :
#   * xsol = [0.9072339603302207, 0.8227554559352911]
#   * f(xsol) = 0.008615650696713988
#   * nb_iters = 6
#   * flag = 0
#   * sol_exacte : [0.9072339605110892, 0.82275545631455]
# Test Summary:         | Pass  Total
# Lagrangien augmenté   |   12     12
# Test.DefaultTestSet("Lagrangien augmenté  ", Any[Test.DefaultTestSet("Avec newton", Any[], 4, false), Test.DefaultTestSet("Avec gct", Any[], 4, false), Test.DefaultTestSet("Avec cauchy", Any[], 4, false)], 0, false)

# %% [markdown]
# ## Interprétation
#  1.Commenter les résultats obtenus, en étudiant notamment les valeurs de $\lambda_k$ et $\mu_k$.
#
#  2.Étudier l'influence du paramètre $\tau$ dans la performance de l'algorithme.
#
#  3.**Supplémentaire** :
#       Que proposez-vous comme méthode pour la résolution des problèmes avec
#       des contraintes à la fois d'égalité et d'inégalité ? Implémenter (si le temps le permet)
#       ce nouvel algorithme

# %% [markdown]
# ## Vos réponses?
#
# 1. On constate que l'algorithme est robuste et est rapidemment convergent. On remarque aussi que les suites $(\lambda_k)$ et $(\mu_k)$ sont toujours strictement positives.
#
# 2. $\tau$ est un paramètre qui fait croître $\mu$.
